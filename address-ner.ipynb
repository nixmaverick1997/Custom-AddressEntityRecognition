# %%
import pandas as pd

# %%
df = pd.read_csv('adresses-01.csv.gz', compression='gzip', header=0, sep=';', quotechar='"', error_bad_lines=False)
df.head()
# Out:
# c:\Users\nixma\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# c:\Users\nixma\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (9,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                    id id_fantoir  numero  rep  \
# 0  01002_w4ld4h_00006        NaN       6  NaN
# 1  01002_6zbsct_01082        NaN    1082  NaN
# 2  01002_6zbsct_01083        NaN    1083  NaN
# 3  01002_9z5vfd_00270        NaN     270  NaN
# 4  01002_a57rqc_00001        NaN       1  NaN
#
#                            nom_voie  code_postal  code_insee  \
# 0                Place du Pese Lait         1640        1002
# 1  Chemin de la Ferm de la Montagne         1640        1002
# ...

# %%
appt_dict={'bâtiment C': 'Logement C402', 'Bâtiment 411': 'Appartement 80.30.32', 'bât jean-corvier': 'Chambre 4',
           'Résidence George-Sand': 'Logement C402, Bâtiment C', 'Résidence Eileen Gray': 'Chambre 32', 'Fac-Habitat Résidence Lavoisier': 'Logement C.456'}

# %%
len(df['nom_commune'].unique())
# Out:
# 393
